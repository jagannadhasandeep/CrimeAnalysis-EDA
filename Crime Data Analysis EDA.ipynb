# %%
#Libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Dataset

data = pd.read_csv(r"C:\Users\sandy\sandeep\datasets\crime.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230545 entries, 0 to 230544
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date Rptd     230545 non-null  object
#  1   DATE OCC      230545 non-null  object
#  2   TIME OCC      230545 non-null  object
#  3   AREA          230545 non-null  int64
#  4   AREA NAME     230545 non-null  object
#  5   Part 1-2      230545 non-null  int64
#  6   Crm Cd        230545 non-null  int64
#  7   Crm Cd Desc   230545 non-null  object
#  8   Vict Age      230545 non-null  int64
#  9   Vict Sex      230545 non-null  object
#  10  Vict Descent  230545 non-null  object
#  11  Premis Desc   230545 non-null  object
#  12  Weapon Desc   230545 non-null  object
#  13  Status Desc   230545 non-null  object
#  14  LOCATION      230545 non-null  object
# dtypes: int64(4), object(11)
# memory usage: 26.4+ MB

# %%
data.head()
# Out:
#     Date Rptd    DATE OCC TIME OCC  AREA  AREA NAME  Part 1-2  Crm Cd  \
# 0  2022-04-12  2020-10-01    00:01    19    Mission         1     821
# 1  2023-01-05  2020-02-01    08:00     2    Rampart         2     812
# 2  2023-03-21  2020-03-15    12:00    19    Mission         2     812
# 3  2023-06-04  2020-07-01    12:00    20    Olympic         2     812
# 4  2022-02-02  2020-02-09    12:00    11  Northeast         2     930
#
#                                          Crm Cd Desc  Vict Age Vict Sex  \
# 0  SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO...         8        F
# 1  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         7        F
# 2  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...        12        F
# 3  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         7        F
# 4             CRIMINAL THREATS - NO WEAPON DISPLAYED        30        F
#
#   Vict Descent                                   Premis Desc  \
# ...

# %%
data.isnull()
# Out:
#         Date Rptd  DATE OCC  TIME OCC   AREA  AREA NAME  Part 1-2  Crm Cd  \
# 0           False     False     False  False      False     False   False
# 1           False     False     False  False      False     False   False
# 2           False     False     False  False      False     False   False
# 3           False     False     False  False      False     False   False
# 4           False     False     False  False      False     False   False
# ...           ...       ...       ...    ...        ...       ...     ...
# 230540      False     False     False  False      False     False   False
# 230541      False     False     False  False      False     False   False
# 230542      False     False     False  False      False     False   False
# 230543      False     False     False  False      False     False   False
# 230544      False     False     False  False      False     False   False
#
#         Crm Cd Desc  Vict Age  Vict Sex  Vict Descent  Premis Desc  \
# ...

# %%
data.shape
# Out:
# (230545, 15)

# %%
data['Vict Sex'].value_counts()
# Out:
# Vict Sex
# M    111540
# F    105368
# X     13618
# H        19
# Name: count, dtype: int64

# %%
data['Weapon Desc'].value_counts()
# Out:
# Weapon Desc
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)    123563
# UNKNOWN WEAPON/OTHER WEAPON                        24639
# VERBAL THREAT                                      16998
# HAND GUN                                           14710
# SEMI-AUTOMATIC PISTOL                               5198
#                                                    ...
# UZI SEMIAUTOMATIC ASSAULT RIFLE                        7
# ANTIQUE FIREARM                                        6
# M-14 SEMIAUTOMATIC ASSAULT RIFLE                       1
# HECKLER & KOCH 91 SEMIAUTOMATIC ASSAULT RIFLE          1
# MAC-10 SEMIAUTOMATIC ASSAULT WEAPON                    1
# Name: count, Length: 77, dtype: int64

# %%
data['LOCATION'].value_counts()
# Out:
# LOCATION
# 6TH                                         774
# 800 N  ALAMEDA                      ST      698
# 7TH                                         696
# 6TH                          ST             696
# 7TH                          ST             648
#                                            ...
# 1800    LINDA FLORA                  DR       1
# 3300    COUNCIL                      ST       1
# 14100    VALLEYHEART                  DR      1
# 1600    RODNEY                       DR       1
# 3000    BUDAU                        AV       1
# Name: count, Length: 35528, dtype: int64

# %%
data['Crm Cd Desc'].value_counts()
# Out:
# Crm Cd Desc
# BATTERY - SIMPLE ASSAULT                          53070
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT    38259
# INTIMATE PARTNER - SIMPLE ASSAULT                 32792
# ROBBERY                                           22846
# CRIMINAL THREATS - NO WEAPON DISPLAYED            13695
#                                                   ...
# COUNTERFEIT                                           1
# DRIVING WITHOUT OWNER CONSENT (DWOC)                  1
# CHILD ABANDONMENT                                     1
# TILL TAP - PETTY ($950 & UNDER)                       1
# DISHONEST EMPLOYEE - PETTY THEFT                      1
# Name: count, Length: 116, dtype: int64

# %%
plt.figsize = (10,20)
sns.histplot(data ,y="AREA NAME",x="Vict Sex")
# Out:
# <Axes: xlabel='Vict Sex', ylabel='AREA NAME'>

# %%
plt.figsize = (1000,100)
sns.displot(data, x="Vict Age",y="Status Desc")

# %%
plt.figsize = (10,20)
sns.relplot(data ,y="Vict Age", x="Vict Sex")

# %%
plt.figsize = (100,100)
sns.barplot(data , x="TIME OCC", y="Crm Cd")
# Out:
# <Axes: xlabel='TIME OCC', ylabel='Crm Cd'>

# %%
sns.lmplot(y="Vict Age", x="Crm Cd", data=data)

# %%
sns.relplot(data=data, x="Vict Descent", y="Vict Sex", kind="line")

# %%
data.columns
# Out:
# Index(['Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME', 'Part 1-2',
#        'Crm Cd', 'Crm Cd Desc', 'Vict Age', 'Vict Sex', 'Vict Descent',
#        'Premis Desc', 'Weapon Desc', 'Status Desc', 'LOCATION'],
#       dtype='object')

# %%
data.tail()
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 230540  2023-08-27  2023-08-27    00:30    15  N Hollywood         1     761
# 230541  2023-07-24  2023-07-24    14:00     6    Hollywood         1     210
# 230542  2023-12-15  2023-12-14    11:05    16     Foothill         1     210
# 230543  2023-07-08  2023-07-08    12:30     1      Central         2     626
# 230544  2023-03-22  2023-03-22    10:00    16     Foothill         1     230
#
#                                            Crm Cd Desc  Vict Age Vict Sex  \
# 230540                                 BRANDISH WEAPON        38        M
# 230541                                         ROBBERY        23        F
# 230542                                         ROBBERY        65        F
# 230543               INTIMATE PARTNER - SIMPLE ASSAULT        35        M
# 230544  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        25        F
#
#        Vict Descent             Premis Desc  \
# ...

# %%
#hightest crime rate

top_crime_locations = data['AREA NAME'].value_counts().head(10)
top_crime_locations_data = top_crime_locations.reset_index()
top_crime_locations_data.columns = ['AREA NAME', 'Crime Count']

print(top_crime_locations_data)
# Out:
#      AREA NAME  Crime Count
# 0  77th Street        20045
# 1      Central        18206
# 2    Southeast        15309
# 3    Hollywood        14463
# 4       Newton        14071
# 5    Southwest        13926
# 6      Rampart        13229
# 7      Olympic        12325
# 8      Pacific        10713
# 9       Harbor         9386

# %%
#Least crime rate

crime_counts = data['AREA NAME'].value_counts()
least_crime_areas = crime_counts[crime_counts == crime_counts.min()]

print("Least crime area names:")
print(least_crime_areas)
# Out:
# Least crime area names:
# AREA NAME
# Foothill    7140
# Name: count, dtype: int64

# %%
#Minors in the crime
#(ages 10-19)
minors_data = data[(data['Vict Age'] >= 10) & (data['Vict Age'] <= 19)]
print(minors_data)
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 2       2023-03-21  2020-03-15    12:00    19      Mission         2     812
# 10      2023-02-08  2020-09-01    12:00    15  N Hollywood         2     812
# 17      2022-01-15  2020-10-10    08:20    12  77th Street         1     820
# 18      2023-08-21  2020-01-01    15:30    13       Newton         2     812
# 19      2022-10-16  2020-07-01    18:00     5       Harbor         2     812
# ...            ...         ...      ...   ...          ...       ...     ...
# 230485  2023-02-17  2023-02-17    15:40    14      Pacific         2     624
# 230486  2023-08-19  2023-08-19    19:45    18    Southeast         2     930
# 230494  2023-04-27  2023-04-26    09:15    19      Mission         2     860
# 230507  2023-05-20  2023-05-20    18:20     3    Southwest         1     210
# 230532  2023-10-03  2023-10-03    02:40    10  West Valley         1     236
#
# ...

# %%
minors_data = data[(data['Vict Age'] >= 10) & (data['Vict Age'] <= 19)]

# Count incidents per crime type
crime_counts = minors_data['Crm Cd Desc'].value_counts().reset_index()
crime_counts.columns = ['Crime Type', 'Count']

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(data=crime_counts, x='Crime Type', y='Count', palette='viridis')
plt.title('Number of Crimes Involving Minors (Ages 10-19)')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Crime Type')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sandy\AppData\Local\Temp\ipykernel_18624\1249961388.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=crime_counts, x='Crime Type', y='Count', palette='viridis')

# %%
data.isnull().sum()
# Out:
# Date Rptd       0
# DATE OCC        0
# TIME OCC        0
# AREA            0
# AREA NAME       0
# Part 1-2        0
# Crm Cd          0
# Crm Cd Desc     0
# Vict Age        0
# Vict Sex        0
# Vict Descent    0
# Premis Desc     0
# Weapon Desc     0
# Status Desc     0
# LOCATION        0
# dtype: int64

# %%
#To get a specific row
data[data.index == 4]
# Out:
#     Date Rptd    DATE OCC TIME OCC  AREA  AREA NAME  Part 1-2  Crm Cd  \
# 4  2022-02-02  2020-02-09    12:00    11  Northeast         2     930
#
#                               Crm Cd Desc  Vict Age Vict Sex Vict Descent  \
# 4  CRIMINAL THREATS - NO WEAPON DISPLAYED        30        F            W
#
#               Premis Desc                  Weapon Desc  Status Desc  \
# 4  SINGLE FAMILY DWELLING  UNKNOWN WEAPON/OTHER WEAPON  Adult Other
#
#                                   LOCATION
# 4  2800    WAVERLY                      DR

# %%
#Isolating tweo or more rows using []
#Similarly, two or more rows can be returned using the .isin() method instead of a == operator.
data[data.index.isin(range(4,21))]
# Out:
#      Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 4   2022-02-02  2020-02-09    12:00    11    Northeast         2     930
# 5   2022-04-28  2020-03-30    16:30     8      West LA         2     624
# 6   2021-09-27  2020-11-26    20:00    12  77th Street         2     930
# 7   2022-01-06  2020-10-30    00:01    15  N Hollywood         2     812
# 8   2023-06-02  2020-05-31    04:30     6    Hollywood         1     310
# 9   2023-11-27  2020-09-13    21:00     8      West LA         2     626
# 10  2023-02-08  2020-09-01    12:00    15  N Hollywood         2     812
# 11  2022-04-07  2020-01-01    08:00    12  77th Street         2     812
# 12  2022-07-06  2020-06-30    14:00     3    Southwest         2     626
# 13  2022-03-21  2020-10-01    22:00     2      Rampart         1     210
# 14  2023-05-22  2020-05-08    12:00    15  N Hollywood         2     626
# 15  2022-10-13  2020-10-13    12:00    15  N Hollywood         2     860
# ...

# %%
data.iloc[5:20]
# Out:
#      Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 5   2022-04-28  2020-03-30    16:30     8      West LA         2     624
# 6   2021-09-27  2020-11-26    20:00    12  77th Street         2     930
# 7   2022-01-06  2020-10-30    00:01    15  N Hollywood         2     812
# 8   2023-06-02  2020-05-31    04:30     6    Hollywood         1     310
# 9   2023-11-27  2020-09-13    21:00     8      West LA         2     626
# 10  2023-02-08  2020-09-01    12:00    15  N Hollywood         2     812
# 11  2022-04-07  2020-01-01    08:00    12  77th Street         2     812
# 12  2022-07-06  2020-06-30    14:00     3    Southwest         2     626
# 13  2022-03-21  2020-10-01    22:00     2      Rampart         1     210
# 14  2023-05-22  2020-05-08    12:00    15  N Hollywood         2     626
# 15  2022-10-13  2020-10-13    12:00    15  N Hollywood         2     860
# 16  2023-08-16  2020-08-27    21:00     1      Central         1     236
# ...

# %%
data.head(20)
# Out:
#      Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 0   2022-04-12  2020-10-01    00:01    19      Mission         1     821
# 1   2023-01-05  2020-02-01    08:00     2      Rampart         2     812
# 2   2023-03-21  2020-03-15    12:00    19      Mission         2     812
# 3   2023-06-04  2020-07-01    12:00    20      Olympic         2     812
# 4   2022-02-02  2020-02-09    12:00    11    Northeast         2     930
# 5   2022-04-28  2020-03-30    16:30     8      West LA         2     624
# 6   2021-09-27  2020-11-26    20:00    12  77th Street         2     930
# 7   2022-01-06  2020-10-30    00:01    15  N Hollywood         2     812
# 8   2023-06-02  2020-05-31    04:30     6    Hollywood         1     310
# 9   2023-11-27  2020-09-13    21:00     8      West LA         2     626
# 10  2023-02-08  2020-09-01    12:00    15  N Hollywood         2     812
# 11  2022-04-07  2020-01-01    08:00    12  77th Street         2     812
# ...

# %%
data.tail(20)
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 230525  2023-10-23  2023-09-24    04:00    13       Newton         1     230
# 230526  2023-04-04  2023-04-04    09:10    12  77th Street         2     624
# 230527  2023-03-05  2023-03-04    17:35     9     Van Nuys         2     624
# 230528  2023-02-16  2023-02-16    10:30    20      Olympic         1     761
# 230529  2023-08-14  2023-08-14    09:30    18    Southeast         1     230
# 230530  2023-09-25  2023-09-25    17:40     6    Hollywood         1     761
# 230531  2023-10-02  2023-10-01    22:05     3    Southwest         2     624
# 230532  2023-10-03  2023-10-03    02:40    10  West Valley         1     236
# 230533  2023-12-22  2023-12-21    16:00    12  77th Street         2     624
# 230534  2023-06-07  2023-06-07    20:45     5       Harbor         2     624
# 230535  2023-06-07  2023-06-07    22:03    13       Newton         2     624
# ...

# %%
status_counts = data['Vict Sex'].value_counts()
plt.figure(figsize=(10, 10))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140)
plt.show()

# %%
sns.boxplot(x="Vict Age", y="AREA NAME", data=data)

plt.xlabel("Vict Age")
plt.ylabel("AREA NAME")
plt.show()

# %%
sns.violinplot(x="Crm Cd", y="Vict Sex", data=data)

plt.xlabel("Crm Cd")
plt.ylabel("Vict Sex")
plt.show()

# %%
corr_matrix = data.select_dtypes(include=['number']).corr()

# Create a heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True, cmap="crest", linewidths=0.5)

plt.show()

# %%
sns.pairplot(data.select_dtypes(include=['number']))

plt.show()
